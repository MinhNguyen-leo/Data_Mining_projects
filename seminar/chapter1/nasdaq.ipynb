# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import nasdaqdatalink

# %% [markdown]
# ### Authenticate API key

# %%
nasdaqdatalink.ApiConfig.api_key = "YOUR_KEY_HERE"

# %% [markdown]
# ### Download data

# %%
df = nasdaqdatalink.get(dataset="WIKI/AAPL",
                        start_date="2011-01-01", 
                        end_date="2017-12-31")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\LE DINH\anaconda3\Lib\site-packages\requests\models.py:976, in Response.json(self, **kwargs)
#     975 try:
# --> 976     return complexjson.loads(self.text, **kwargs)
#     977 except JSONDecodeError as e:
#     978     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     979     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\LE DINH\anaconda3\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# ...

# %% [markdown]
# ### Inspect data

# %%
print(f"Downloaded {len(df)} rows of data.")
df.head()

# %% [markdown]
# ## Additionally

# %% [markdown]
# ### Using the get_table function to download data

# %%
COLUMNS = ["ticker", "date", "adj_close"]
df = nasdaqdatalink.get_table("WIKI/PRICES", 
                              ticker=["AAPL", 
df.head()
"MSFT", "INTC"], 
                              qopts={"columns": COLUMNS}, 
                              date={"gte": 
"2011-01-01", 
"lte": "2021-12-31"}, 
                              paginate=True)

# %% [markdown]
# ### Pivot the data from long format to wide

# %%
df = df.set_index("date")
df_wide = df.pivot(columns="ticker")
df_wide.head()
