# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
import yfinance as yf

# %% [markdown]
# ### Download data

# %%
df = yf.download("AAPL",
                 start="2011-01-01",
                 end="2021-12-31",
                 progress=False)

# %% [markdown]
# ### Inspect the downloaded data

# %%
print(f"Downloaded {len(df)} rows of data.")
df
# Out:
# Downloaded 2768 rows of data.
# Price            Close        High         Low        Open     Volume
# Ticker            AAPL        AAPL        AAPL        AAPL       AAPL
# Date
# 2011-01-03    9.874907    9.895582    9.733183    9.757153  445138400
# 2011-01-04    9.926446    9.962701    9.832362    9.960903  309080800
# 2011-01-05   10.007644   10.017831    9.872810    9.874309  255519600
# 2011-01-06    9.999555   10.045098    9.974685   10.029217  300428800
# 2011-01-07   10.071166   10.078057    9.944722   10.007345  311931200
# ...                ...         ...         ...         ...        ...
# 2021-12-23  172.496643  173.054417  171.508325  172.075879   68356600
# 2021-12-27  176.459732  176.547797  173.269704  173.289264   74919600
# 2021-12-28  175.442047  177.438273  174.698364  176.293385   79144300
# 2021-12-29  175.530090  176.753262  174.316698  175.481160   62348900
# 2021-12-30  174.375443  176.694587  174.267803  175.618190   59773000
#
# ...

# %% [markdown]
# ### Additionally

# %% [markdown]
# #### Alternative way of download yfiance data

# %%
aapl_data = yf.Ticker("AAPL")

# %% [markdown]
# #### Showing data history

# %%
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-02-19 00:00:00-05:00  262.600006  264.480011  260.049988  260.579987
# 2026-02-20 00:00:00-05:00  258.970001  264.750000  258.160004  264.579987
# 2026-02-23 00:00:00-05:00  263.489990  269.429993  263.380005  266.179993
# 2026-02-24 00:00:00-05:00  267.859985  274.890015  267.709991  272.140015
# 2026-02-25 00:00:00-05:00  271.779999  274.940002  271.049988  274.230011
# 2026-02-26 00:00:00-05:00  274.950012  276.109985  270.799988  272.950012
# 2026-02-27 00:00:00-05:00  272.809998  272.809998  262.890015  264.179993
# 2026-03-02 00:00:00-05:00  262.410004  266.529999  260.200012  264.720001
# 2026-03-03 00:00:00-05:00  263.480011  265.559998  260.130005  263.750000
# 2026-03-04 00:00:00-05:00  264.649994  266.149994  261.420013  262.519989
# 2026-03-05 00:00:00-05:00  260.790009  261.559998  257.250000  260.290009
# 2026-03-06 00:00:00-05:00  258.630005  258.769989  254.369995  257.459991
# ...
